# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_arch
from statsmodels.tsa.stattools import q_stat
from statsmodels.tsa.stattools import acf
import warnings
warnings.simplefilter('ignore')
from arch import arch_model

# %matplotlib inline

# %% [markdown]
# ### To run this code, please make sure the 40 stocks files are stored in the a sub directory named "stock".

# %%
def getForecast_GARCH(N):
    stock='stock/stock'+str(N)+'.txt'
    data = np.genfromtxt(fname=stock,delimiter=",",skip_header=True,dtype=np.float,usecols=(1))
    df_data=pd.DataFrame(data=data,columns=['Price'])
    am = arch_model(df_data*100, p=1, o=0, q=1,vol='GARCH',dist='normal')
    res = am.fit(update_freq=5, disp='off')
    return res

# %%
def getQuantile15_GARCH_simulation(N):
    res=getForecast_GARCH(N)
    forecasts = res.forecast(horizon=10, method='bootstrap',simulations=10000)
    quantile15=np.quantile(forecasts.simulations.values[-1],q=0.15,axis=0)/100
    return np.array(quantile15)

# %%
def getQuantile15_GARCH_theoretical(N):
    res=getForecast_GARCH(N)
    forecasts = res.forecast(horizon=10, method='analytic')
    s=np.sqrt(forecasts.variance.values[-1]/10000)
    quantile15=-1.03643*s
    return np.array(quantile15)

# %%
def getForecast(N):
    stock='stock/stock'+str(N)+'.txt'
    data = np.genfromtxt(fname=stock,delimiter=",",skip_header=True,dtype=np.float,usecols=(1))
    df_data=pd.DataFrame(data=data,columns=['Price'])
    am = arch_model(df_data*100, p=1, o=1, q=1,vol='EGARCH', dist='normal')
    res = am.fit(update_freq=5, disp='off')
    return res

# %%
def getQuantile15(N):
    res=getForecast(N)
    forecasts = res.forecast(horizon=10, method='simulation',simulations=10000)
    quantile15=np.quantile(forecasts.simulations.values[-1],q=0.15,axis=0)/100
    return np.array(quantile15)

# %% [markdown]
# #### Specify which stock to test.

# %%
N=17

# %%
stock='stock/stock'+str(N)+'.txt'
data = np.genfromtxt(fname=stock,delimiter=",",skip_header=True,dtype=np.float,usecols=(1))
df_data=pd.DataFrame(data=data,columns=['Price'])

# %%
fig=plt.figure(figsize=(12,5))
ax = fig.add_subplot(111)
ax.set_title(str('Daily resolution log differenced price for stock '+str(N)))
ax.text(0.5,-0.12, "Fig. 2.1", size=12, ha="center", transform=ax.transAxes,weight='bold')
plt.plot(data)

# %% [markdown]
# #### Engle's LM test:

# %%
print("p value is {:5.6f}".format(het_arch(data)[1]))
# Out:
# p value is 0.003577

# %% [markdown]
# The p-value is less than 1% hence the null hypothesis can be rejected at 1% significance level,
# meaning that the ARCH affects are quite significant in the daily log returns.

# %% [markdown]
# #### ACF

# %%
fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(111)
ax.text(0.5,-0.1, "Fig. 2.2", size=12, ha="center", transform=ax.transAxes,weight='bold')
plot_acf(data,lags=np.arange(0,48),ax=ax);

# %%
fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(111)
ax.text(0.5,-0.1, "Fig. 2.3", size=12, ha="center", transform=ax.transAxes,weight='bold')
plot_acf(data**2,lags=np.arange(0,48),ax=ax);

# %%
res=getForecast_GARCH(N)
forecasts = res.forecast(horizon=10, method='bootstrap',simulations=10000)

# %%
res.summary
# Out:
# <bound method ARCHModelResult.summary of                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                      -0.002
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.002
# Vol Model:                      GARCH   Log-Likelihood:               -292.959
# Distribution:                  Normal   AIC:                           593.918
# Method:            Maximum Likelihood   BIC:                           605.960
#                                         No. Observations:                  150
# Date:                Wed, Apr 24 2019   Df Residuals:                      146
# Time:                        14:08:29   Df Model:                            4
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.0230      0.136      0.169      0.866 [ -0.244,  0.290]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.3909      0.277      1.410      0.158   [ -0.152,  0.934]
# alpha[1]       0.1860  8.833e-02      2.106  3.525e-02 [1.286e-02,  0.359]
# beta[1]        0.7004      0.116      6.024  1.701e-09   [  0.473,  0.928]
# ==========================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x1c363f9198>

# %% [markdown]
# The 15% lower quantile by the whole 150 samples

# %%
np.quantile(data,q=0.15)
# Out:
# -0.01571551512005841

# %% [markdown]
# #### The forecast result using GARCH Model.

# %% [markdown]
# 1. By simulation(Bootstrap)

# %%
result_data_garch_simulation=[]
for i in np.arange(1,41):
    a=getQuantile15_GARCH_simulation(i)
    result_data_garch_simulation.append(a)

# %% [markdown]
# 2. Theoretical

# %%
result_data_garch_theoretical=[]
for i in np.arange(1,41):
    a=getQuantile15_GARCH_theoretical(i)
    result_data_garch_theoretical.append(a)

# %% [markdown]
# Examine result for specified stock

# %%
result_data_garch_simulation[N-1] # for stock N
# Out:
# array([-0.01457873, -0.01550012, -0.01486237, -0.01479663, -0.01518194,
#        -0.01527445, -0.01507978, -0.01491277, -0.01578021, -0.01534382])

# %%
result_data_garch_theoretical[N-1] # for stock N
# Out:
# array([-0.01719439, -0.01743703, -0.01764932, -0.01783537, -0.01799868,
#        -0.01814221, -0.01826849, -0.0183797 , -0.01847771, -0.01856416])

# %% [markdown]
# #### The forecast result using EGARCH Model.

# %%
result_data=[]
for i in np.arange(1,41):
    a=getQuantile15(i)
    result_data.append(a)
# Out:
# /anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:577: ConvergenceWarning:
# The optimizer returned code 9. The message is:
# Iteration limit exceeded
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:577: ConvergenceWarning:
# The optimizer returned code 9. The message is:
# Iteration limit exceeded
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:577: ConvergenceWarning:
# The optimizer returned code 9. The message is:
# Iteration limit exceeded
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:577: ConvergenceWarning:
# The optimizer returned code 9. The message is:
# Iteration limit exceeded
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:577: ConvergenceWarning:
# The optimizer returned code 9. The message is:
# Iteration limit exceeded
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:577: ConvergenceWarning:
# The optimizer returned code 9. The message is:
# Iteration limit exceeded
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:577: ConvergenceWarning:
# The optimizer returned code 9. The message is:
# Iteration limit exceeded
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:577: ConvergenceWarning:
# The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)

# %% [markdown]
# As shown above, convergence issue exists when fitting EGARCH

# %%
result_data[N-1] #the result is obviously wrong
# Out:
# array([-5.13957551, -5.1189621 , -5.16654122, -5.33449199, -5.32155142,
#        -5.53016189, -5.51771688, -5.44485778, -5.73488379, -5.69304422])

# %% [markdown]
# #### By the above model diagnostics, we prefer GARCH model

# %%
result_data=np.array(result_data).T
result_data_garch_simulation=np.array(result_data_garch_simulation).T
result_data_garch_theoretical=np.array(result_data_garch_theoretical).T

# %%
result_data.shape
# Out:
# (10, 40)

# %%
data_concat=np.concatenate((result_data,result_data_garch_simulation,result_data_garch_theoretical),axis=0)

# %%
#np.savetxt('comparison/three_in_one.csv',data_concat,delimiter=',')

# %% [markdown]
# ### Decide to use the GARCH Bootstrap Result for output

# %%
np.savetxt('../Result in CSV/Li_Scenario2.csv', result_data_garch_simulation, delimiter=',')

# %% [markdown]
# assume normal distribution, 15% lower quantile

# %%
s=np.sqrt(forecasts.variance.values[-1]/10000)
-1.03643*s
# Out:
# array([-0.01553749, -0.01704935, -0.01797514, -0.01859034, -0.01900153,
#        -0.01920203, -0.01951485, -0.01925795, -0.01927147, -0.01937331])

# %% [markdown]
# By simulation, 15% lower quantile

# %%
res=getForecast_GARCH(N)
forecasts = res.forecast(horizon=10, method='analytic')

# %%
forecasts.mean.iloc[-1]
# Out:
# h.01    0.022989
# h.02    0.022989
# h.03    0.022989
# h.04    0.022989
# h.05    0.022989
# h.06    0.022989
# h.07    0.022989
# h.08    0.022989
# h.09    0.022989
# h.10    0.022989
# Name: 149, dtype: float64

# %%
forecasts.variance.iloc[-1]
# Out:
# h.01    2.752287
# h.02    2.830513
# h.03    2.899852
# h.04    2.961314
# h.05    3.015793
# h.06    3.064083
# h.07    3.106886
# h.08    3.144827
# h.09    3.178457
# h.10    3.208267
# Name: 149, dtype: float64

# %%
s=np.sqrt(forecasts.variance.values[-1]/10000)
quantile15=-1.03643*s

# %%
quantile15
# Out:
# array([-0.01719439, -0.01743703, -0.01764932, -0.01783537, -0.01799868,
#        -0.01814221, -0.01826849, -0.0183797 , -0.01847771, -0.01856416])
