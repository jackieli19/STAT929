# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import correlate
import numpy as np

import statsmodels as sm
from statsmodels.tsa.stattools import ccf
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.api import VAR, DynamicVAR
from statsmodels.tsa.base.datetools import dates_from_str
from statsmodels.tsa.vector_ar import plotting
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from pandas import DataFrame
from pandas import concat
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from numpy import concatenate
from math import sqrt
from sklearn.metrics import mean_squared_error

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
#define function for ADF test
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
def tsplot(y, title, lags=None, figsize=(12, 6)):
    fig = plt.figure(figsize=figsize)
    layout = (2, 2)
    ts_ax = plt.subplot2grid(layout, (0, 0))
    hist_ax = plt.subplot2grid(layout, (0, 1))
    acf_ax = plt.subplot2grid(layout, (1, 0))
    pacf_ax = plt.subplot2grid(layout, (1, 1))
    plt.text(-6,-1.4, "Fig. 4.3", size=12, ha="center",weight='bold');
    y.plot(ax=ts_ax)
    ts_ax.set_title(title, fontsize=12, fontweight='bold')
    y.plot(ax=hist_ax, kind='hist', bins=25)
    hist_ax.set_title('Histogram')
    plot_acf(y, lags=lags, ax=acf_ax)
    plot_pacf(y, lags=lags, ax=pacf_ax)
    sns.despine()
    plt.tight_layout()
    plt.show()
    return ts_ax, acf_ax, pacf_ax

# %% [markdown]
# Make sure the finalized data output is saved in Scenario3's folder

# %%
dataset = pd.read_csv('../Scenario3/data_merged_final.csv',index_col=0)

# %%
dataset.tail()
# Out:
#              Beer      Car  Steel    Gas  Electricity  Temp
# Date
# 1991-11-01  192.0  23870.0  415.0  42145        12449  23.4
# 1991-12-01  192.0  16001.0  568.0  38698        12489  24.2
# 1992-01-01  147.0  11055.0  577.0  38963        12621  25.3
# 1992-02-01  133.0  21181.0  517.0  38690        12380  25.0
# 1992-03-01  163.0  25467.0  558.0  39792        13023  25.4

# %%
CsI=dataset['Beer']
WLS=dataset['Steel']

# %%
import scipy.signal as ss
import numpy as np
import matplotlib.pyplot as plt

maxlags = 10
result = result = ss.correlate(CsI - np.mean(CsI), WLS - np.mean(WLS), method='direct')/(np.std(CsI)*np.std(WLS)*len(CsI))
lo = (len(result)-1)//2-10 #just get +/- 10 elements around lag 0
hi = (len(result)-1)//2+11

locs = np.arange(lo, hi)
# for loc in locs:
#     print(str(loc)+'\t:\t'+str(result[loc]))

#Make a plot like ccf
f, ax = plt.subplots(figsize=(12,4))
ax.stem(np.arange(-10,11), result[lo:hi], '-.')
ax.set_xticks(np.arange(-10,11))
ax.text(0.5,-0.15, "Fig. 4.1", size=12, ha="center", transform=ax.transAxes,weight='bold')
ax.set_title('Beer vs Steel CCF')
plt.show()

# %%
dataset.plot(subplots=True,figsize=(12,12))
plt.text(215,8, "Fig. 4.2", size=12, ha="center",weight='bold');

# %%
tsplot(dataset['Gas'],'Gas',lags=np.arange(0,40))
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1c42b1bc88>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x101e4ee10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x101e7d320>)

# %% [markdown]
# #### Stationarity Test

# %%
adf_test(dataset['Beer'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.007111
# p-value                          0.283464
# #Lags Used                      17.000000
# Number of Observations Used    417.000000
# Critical Value (1%)             -3.446129
# Critical Value (5%)             -2.868496
# Critical Value (10%)            -2.570475
# dtype: float64

# %%
adf_test(dataset['Temp'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.333879e+00
# p-value                        2.862096e-08
# #Lags Used                     1.800000e+01
# Number of Observations Used    4.160000e+02
# Critical Value (1%)           -3.446168e+00
# Critical Value (5%)           -2.868513e+00
# Critical Value (10%)          -2.570484e+00
# dtype: float64

# %% [markdown]
# For temperature, the test statistic < critical value, which implies that the series is stationary.

# %%
adf_test(dataset['Car'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.737860
# p-value                          0.067713
# #Lags Used                      13.000000
# Number of Observations Used    421.000000
# Critical Value (1%)             -3.445979
# Critical Value (5%)             -2.868430
# Critical Value (10%)            -2.570440
# dtype: float64

# %% [markdown]
# For car, the test statistic < critical value in 10% significance level, which implies that the series is stationary. The cas has growth in the beginning but tends to stationay later.

# %%
adf_test(dataset['Steel'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.252618
# p-value                          0.187705
# #Lags Used                      12.000000
# Number of Observations Used    422.000000
# Critical Value (1%)             -3.445941
# Critical Value (5%)             -2.868413
# Critical Value (10%)            -2.570431
# dtype: float64

# %%
adf_test(dataset['Gas'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   0.205778
# p-value                          0.972584
# #Lags Used                      17.000000
# Number of Observations Used    417.000000
# Critical Value (1%)             -3.446129
# Critical Value (5%)             -2.868496
# Critical Value (10%)            -2.570475
# dtype: float64

# %%
adf_test(dataset['Electricity'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   1.563761
# p-value                          0.997745
# #Lags Used                      17.000000
# Number of Observations Used    417.000000
# Critical Value (1%)             -3.446129
# Critical Value (5%)             -2.868496
# Critical Value (10%)            -2.570475
# dtype: float64

# %% [markdown]
# #### Transformation to stationary series for non-stationary series.

# %% [markdown]
# Use log transform for **steel**.

# %%
dataset['Steel_log'] = np.log(dataset['Steel'])
dataset['Steel_log_diff'] = dataset['Steel_log'] - dataset['Steel_log'].shift(1)
adfuller(dataset['Steel_log_diff'].dropna())
# Out:
# (-6.287739626234397,
#  3.662730800933553e-08,
#  13,
#  420,
#  {'1%': -3.4460159927788574,
#   '5%': -2.868446209372638,
#   '10%': -2.570448781179138},
#  -897.0581197796027)

# %% [markdown]
# For **gas & electricity**, first seasonal difference. then difference by 1.

# %%
dataset['Gas_diff_seas'] = dataset['Gas'] - dataset['Gas'].shift(12)
dataset['Gas_diff'] = dataset['Gas_diff_seas'] - dataset['Gas_diff_seas'].shift(1)

# %%
adfuller(dataset['Gas_diff'].dropna())
# Out:
# (-7.4238058254419075,
#  6.629388763873165e-11,
#  18,
#  403,
#  {'1%': -3.4466811208382437,
#   '5%': -2.8687386420385494,
#   '10%': -2.5706046655665635},
#  6970.282319837302)

# %%
dataset['Electricity_diff_seas'] = dataset['Electricity'] - dataset['Electricity'].shift(12)
dataset['Electricity_diff'] = dataset['Electricity_diff_seas'] - dataset['Electricity_diff_seas'].shift(1)

# %%
adfuller(dataset['Electricity_diff'].dropna())
# Out:
# (-6.32664313158626,
#  2.97516703220987e-08,
#  17,
#  404,
#  {'1%': -3.44664043608676,
#   '5%': -2.868720756230461,
#   '10%': -2.5705951311145965},
#  5275.094116151984)

# %%
dataset_stationary=dataset.drop(['Steel','Gas','Electricity',\
                                 'Steel_log','Gas_diff_seas','Electricity_diff_seas'],axis=1).iloc[13:]

# %% [markdown]
# now we have got the stationary series

# %%
dataset_stationary.head()
#dataset_stationary.to_csv('dataset_stationary.csv',sep=',')
# Out:
#             Beer           Car  Temp  Steel_log_diff  Gas_diff  \
# Date
# 1957-02-01  82.8  13985.911224  24.0       -0.092787       0.0
# 1957-03-01  83.3  14767.651312  24.1        0.069590      84.0
# 1957-04-01  80.0  14270.452770  23.5       -0.030697     -63.0
# 1957-05-01  80.4  15046.366905  21.1        0.014658      75.0
# 1957-06-01  67.5  14187.495032  20.3       -0.008525    -180.0
#
#             Electricity_diff
# Date
# 1957-02-01             -58.0
# 1957-03-01              67.0
# 1957-04-01              -8.0
# 1957-05-01               2.0
# 1957-06-01             -97.0

# %% [markdown]
# #### Training by LSTM

# %%
values = dataset_stationary.values
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
# specify the number of lag hours
n_days = 24
n_features = 6

# frame as supervised learning
reframed = series_to_supervised(scaled, n_days, n_days)

#reframed.to_csv('input_LSTM.csv')

# %%
# split into train and test sets
values = reframed.values
n_train_days = 330
train = values[:n_train_days, :]
test = values[n_train_days:, :]

# %%
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:,n_obs::n_features]
test_X, test_y = test[:, :n_obs], test[:,n_obs::n_features]
print(train_X.shape, len(train_X), train_y.shape)
# Out:
# (330, 144) 330 (330, 24)

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (330, 24, 6) (330, 24) (45, 24, 6) (45, 24)

# %%
train_X_all, train_y_all = values[:, :n_obs], values[:,n_obs::n_features]
train_X_all = train_X_all.reshape((train_X_all.shape[0], n_days, n_features))

# %%
train_X_all.shape,train_y_all.shape
# Out:
# ((375, 24, 6), (375, 24))

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(n_days))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X_all, train_y_all, epochs=200, batch_size=10, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 375 samples, validate on 45 samples
# Epoch 1/200
#  - 3s - loss: 0.2207 - val_loss: 0.1360
# Epoch 2/200
#  - 1s - loss: 0.1913 - val_loss: 0.1210
# Epoch 3/200
#  - 1s - loss: 0.1923 - val_loss: 0.1177
# Epoch 4/200
#  - 1s - loss: 0.1839 - val_loss: 0.1152
# Epoch 5/200
#  - 1s - loss: 0.1770 - val_loss: 0.1150
# Epoch 6/200
#  - 1s - loss: 0.1694 - val_loss: 0.1147
# Epoch 7/200
#  - 1s - loss: 0.1604 - val_loss: 0.1151
# Epoch 8/200
#  - 1s - loss: 0.1496 - val_loss: 0.1128
# Epoch 9/200
#  - 1s - loss: 0.1377 - val_loss: 0.1097
# Epoch 10/200
#  - 1s - loss: 0.1290 - val_loss: 0.1090
# Epoch 11/200
#  - 1s - loss: 0.1125 - val_loss: 0.1037
# Epoch 12/200
#  - 1s - loss: 0.1018 - val_loss: 0.0976
# Epoch 13/200
#  - 1s - loss: 0.0881 - val_loss: 0.0897
# Epoch 14/200
#  - 1s - loss: 0.1005 - val_loss: 0.0907
# Epoch 15/200
#  - 1s - loss: 0.0806 - val_loss: 0.0882
# Epoch 16/200
#  - 1s - loss: 0.0926 - val_loss: 0.0860
# Epoch 17/200
#  - 1s - loss: 0.0785 - val_loss: 0.0865
# Epoch 18/200
#  - 1s - loss: 0.0773 - val_loss: 0.0844
# Epoch 19/200
#  - 1s - loss: 0.0758 - val_loss: 0.0842
# Epoch 20/200
#  - 1s - loss: 0.0737 - val_loss: 0.0837
# Epoch 21/200
#  - 1s - loss: 0.0728 - val_loss: 0.0837
# Epoch 22/200
#  - 1s - loss: 0.0719 - val_loss: 0.0835
# Epoch 23/200
#  - 1s - loss: 0.0709 - val_loss: 0.0840
# Epoch 24/200
#  - 1s - loss: 0.0704 - val_loss: 0.0840
# Epoch 25/200
#  - 1s - loss: 0.0697 - val_loss: 0.0840
# Epoch 26/200
#  - 1s - loss: 0.0692 - val_loss: 0.0841
# Epoch 27/200
#  - 1s - loss: 0.0689 - val_loss: 0.0838
# Epoch 28/200
#  - 1s - loss: 0.0687 - val_loss: 0.0837
# Epoch 29/200
#  - 1s - loss: 0.0687 - val_loss: 0.0837
# Epoch 30/200
#  - 1s - loss: 0.0682 - val_loss: 0.0834
# Epoch 31/200
#  - 1s - loss: 0.0682 - val_loss: 0.0836
# Epoch 32/200
#  - 1s - loss: 0.0681 - val_loss: 0.0835
# Epoch 33/200
#  - 1s - loss: 0.0679 - val_loss: 0.0835
# Epoch 34/200
#  - 1s - loss: 0.0678 - val_loss: 0.0831
# Epoch 35/200
#  - 1s - loss: 0.0677 - val_loss: 0.0831
# Epoch 36/200
#  - 1s - loss: 0.0673 - val_loss: 0.0833
# Epoch 37/200
#  - 1s - loss: 0.0673 - val_loss: 0.0831
# Epoch 38/200
#  - 1s - loss: 0.0672 - val_loss: 0.0826
# Epoch 39/200
#  - 1s - loss: 0.0675 - val_loss: 0.0823
# Epoch 40/200
#  - 1s - loss: 0.0673 - val_loss: 0.0821
# Epoch 41/200
#  - 1s - loss: 0.0671 - val_loss: 0.0820
# Epoch 42/200
#  - 1s - loss: 0.0668 - val_loss: 0.0820
# Epoch 43/200
#  - 1s - loss: 0.0668 - val_loss: 0.0816
# Epoch 44/200
#  - 1s - loss: 0.0668 - val_loss: 0.0815
# Epoch 45/200
#  - 1s - loss: 0.0664 - val_loss: 0.0813
# Epoch 46/200
#  - 1s - loss: 0.0667 - val_loss: 0.0808
# Epoch 47/200
#  - 1s - loss: 0.0664 - val_loss: 0.0810
# Epoch 48/200
#  - 1s - loss: 0.0663 - val_loss: 0.0809
# Epoch 49/200
#  - 1s - loss: 0.0666 - val_loss: 0.0801
# Epoch 50/200
#  - 1s - loss: 0.0671 - val_loss: 0.0805
# Epoch 51/200
#  - 1s - loss: 0.0661 - val_loss: 0.0798
# Epoch 52/200
#  - 1s - loss: 0.0660 - val_loss: 0.0796
# Epoch 53/200
#  - 1s - loss: 0.0657 - val_loss: 0.0792
# Epoch 54/200
#  - 1s - loss: 0.0653 - val_loss: 0.0787
# Epoch 55/200
#  - 1s - loss: 0.0648 - val_loss: 0.0781
# Epoch 56/200
#  - 1s - loss: 0.0644 - val_loss: 0.0775
# Epoch 57/200
#  - 1s - loss: 0.0643 - val_loss: 0.0775
# Epoch 58/200
#  - 1s - loss: 0.0642 - val_loss: 0.0770
# Epoch 59/200
#  - 2s - loss: 0.0639 - val_loss: 0.0762
# Epoch 60/200
#  - 1s - loss: 0.0650 - val_loss: 0.0769
# Epoch 61/200
#  - 1s - loss: 0.0647 - val_loss: 0.0773
# Epoch 62/200
#  - 1s - loss: 0.0647 - val_loss: 0.0766
# Epoch 63/200
#  - 1s - loss: 0.0651 - val_loss: 0.0753
# Epoch 64/200
#  - 1s - loss: 0.0650 - val_loss: 0.0755
# Epoch 65/200
#  - 1s - loss: 0.0645 - val_loss: 0.0754
# Epoch 66/200
#  - 1s - loss: 0.0630 - val_loss: 0.0754
# Epoch 67/200
#  - 1s - loss: 0.0621 - val_loss: 0.0753
# Epoch 68/200
#  - 1s - loss: 0.0619 - val_loss: 0.0742
# Epoch 69/200
#  - 1s - loss: 0.0622 - val_loss: 0.0743
# Epoch 70/200
#  - 1s - loss: 0.0622 - val_loss: 0.0734
# Epoch 71/200
#  - 1s - loss: 0.0620 - val_loss: 0.0732
# Epoch 72/200
#  - 1s - loss: 0.0613 - val_loss: 0.0719
# Epoch 73/200
#  - 1s - loss: 0.0616 - val_loss: 0.0716
# Epoch 74/200
#  - 1s - loss: 0.0611 - val_loss: 0.0707
# Epoch 75/200
#  - 1s - loss: 0.0616 - val_loss: 0.0697
# Epoch 76/200
#  - 1s - loss: 0.0602 - val_loss: 0.0694
# Epoch 77/200
#  - 1s - loss: 0.0604 - val_loss: 0.0711
# Epoch 78/200
#  - 1s - loss: 0.0595 - val_loss: 0.0714
# Epoch 79/200
#  - 1s - loss: 0.0591 - val_loss: 0.0702
# Epoch 80/200
#  - 1s - loss: 0.0593 - val_loss: 0.0700
# Epoch 81/200
#  - 1s - loss: 0.0593 - val_loss: 0.0698
# Epoch 82/200
#  - 1s - loss: 0.0595 - val_loss: 0.0695
# Epoch 83/200
#  - 1s - loss: 0.0596 - val_loss: 0.0688
# Epoch 84/200
#  - 1s - loss: 0.0611 - val_loss: 0.0681
# Epoch 85/200
#  - 1s - loss: 0.0620 - val_loss: 0.0665
# Epoch 86/200
#  - 1s - loss: 0.0695 - val_loss: 0.0660
# Epoch 87/200
#  - 1s - loss: 0.0718 - val_loss: 0.0640
# Epoch 88/200
#  - 1s - loss: 0.0630 - val_loss: 0.0632
# Epoch 89/200
#  - 1s - loss: 0.0612 - val_loss: 0.0637
# Epoch 90/200
#  - 1s - loss: 0.0596 - val_loss: 0.0648
# Epoch 91/200
#  - 1s - loss: 0.0609 - val_loss: 0.0652
# Epoch 92/200
#  - 1s - loss: 0.0652 - val_loss: 0.0619
# Epoch 93/200
#  - 1s - loss: 0.0629 - val_loss: 0.0620
# Epoch 94/200
#  - 1s - loss: 0.0648 - val_loss: 0.0612
# Epoch 95/200
#  - 1s - loss: 0.0587 - val_loss: 0.0621
# Epoch 96/200
#  - 1s - loss: 0.0581 - val_loss: 0.0614
# Epoch 97/200
#  - 1s - loss: 0.0575 - val_loss: 0.0618
# Epoch 98/200
#  - 1s - loss: 0.0567 - val_loss: 0.0622
# Epoch 99/200
#  - 1s - loss: 0.0568 - val_loss: 0.0620
# Epoch 100/200
#  - 1s - loss: 0.0570 - val_loss: 0.0614
# Epoch 101/200
#  - 1s - loss: 0.0567 - val_loss: 0.0610
# Epoch 102/200
#  - 1s - loss: 0.0570 - val_loss: 0.0610
# Epoch 103/200
#  - 1s - loss: 0.0567 - val_loss: 0.0605
# Epoch 104/200
#  - 1s - loss: 0.0566 - val_loss: 0.0606
# Epoch 105/200
#  - 1s - loss: 0.0569 - val_loss: 0.0612
# Epoch 106/200
#  - 1s - loss: 0.0567 - val_loss: 0.0609
# Epoch 107/200
#  - 1s - loss: 0.0566 - val_loss: 0.0610
# Epoch 108/200
#  - 1s - loss: 0.0568 - val_loss: 0.0609
# Epoch 109/200
#  - 1s - loss: 0.0569 - val_loss: 0.0609
# Epoch 110/200
#  - 1s - loss: 0.0570 - val_loss: 0.0608
# Epoch 111/200
#  - 1s - loss: 0.0574 - val_loss: 0.0607
# Epoch 112/200
#  - 1s - loss: 0.0576 - val_loss: 0.0613
# Epoch 113/200
#  - 2s - loss: 0.0576 - val_loss: 0.0614
# Epoch 114/200
#  - 2s - loss: 0.0579 - val_loss: 0.0607
# Epoch 115/200
#  - 1s - loss: 0.0573 - val_loss: 0.0604
# Epoch 116/200
#  - 1s - loss: 0.0578 - val_loss: 0.0604
# Epoch 117/200
#  - 1s - loss: 0.0588 - val_loss: 0.0607
# Epoch 118/200
#  - 1s - loss: 0.0587 - val_loss: 0.0616
# Epoch 119/200
#  - 1s - loss: 0.0585 - val_loss: 0.0625
# Epoch 120/200
#  - 1s - loss: 0.0578 - val_loss: 0.0628
# Epoch 121/200
#  - 1s - loss: 0.0568 - val_loss: 0.0633
# Epoch 122/200
#  - 1s - loss: 0.0565 - val_loss: 0.0642
# Epoch 123/200
#  - 1s - loss: 0.0561 - val_loss: 0.0636
# Epoch 124/200
#  - 1s - loss: 0.0565 - val_loss: 0.0617
# Epoch 125/200
#  - 1s - loss: 0.0578 - val_loss: 0.0609
# Epoch 126/200
#  - 1s - loss: 0.0596 - val_loss: 0.0601
# Epoch 127/200
#  - 1s - loss: 0.0604 - val_loss: 0.0602
# Epoch 128/200
#  - 2s - loss: 0.0585 - val_loss: 0.0602
# Epoch 129/200
#  - 2s - loss: 0.0604 - val_loss: 0.0602
# Epoch 130/200
#  - 1s - loss: 0.0594 - val_loss: 0.0608
# Epoch 131/200
#  - 1s - loss: 0.0580 - val_loss: 0.0633
# Epoch 132/200
#  - 1s - loss: 0.0675 - val_loss: 0.0609
# Epoch 133/200
#  - 1s - loss: 0.0686 - val_loss: 0.0603
# Epoch 134/200
#  - 1s - loss: 0.0611 - val_loss: 0.0601
# Epoch 135/200
#  - 1s - loss: 0.0577 - val_loss: 0.0605
# Epoch 136/200
#  - 1s - loss: 0.0575 - val_loss: 0.0627
# Epoch 137/200
#  - 1s - loss: 0.0628 - val_loss: 0.0594
# Epoch 138/200
#  - 1s - loss: 0.0616 - val_loss: 0.0598
# Epoch 139/200
#  - 1s - loss: 0.0609 - val_loss: 0.0602
# Epoch 140/200
#  - 1s - loss: 0.0567 - val_loss: 0.0625
# Epoch 141/200
#  - 1s - loss: 0.0614 - val_loss: 0.0588
# Epoch 142/200
#  - 1s - loss: 0.0604 - val_loss: 0.0598
# Epoch 143/200
#  - 1s - loss: 0.0594 - val_loss: 0.0596
# Epoch 144/200
#  - 1s - loss: 0.0559 - val_loss: 0.0620
# Epoch 145/200
#  - 1s - loss: 0.0592 - val_loss: 0.0585
# Epoch 146/200
#  - 1s - loss: 0.0600 - val_loss: 0.0596
# Epoch 147/200
#  - 1s - loss: 0.0573 - val_loss: 0.0594
# Epoch 148/200
#  - 1s - loss: 0.0551 - val_loss: 0.0605
# Epoch 149/200
#  - 1s - loss: 0.0591 - val_loss: 0.0583
# Epoch 150/200
#  - 1s - loss: 0.0608 - val_loss: 0.0593
# Epoch 151/200
#  - 1s - loss: 0.0568 - val_loss: 0.0590
# Epoch 152/200
#  - 1s - loss: 0.0550 - val_loss: 0.0597
# Epoch 153/200
#  - 1s - loss: 0.0583 - val_loss: 0.0582
# Epoch 154/200
#  - 1s - loss: 0.0601 - val_loss: 0.0590
# Epoch 155/200
#  - 1s - loss: 0.0556 - val_loss: 0.0588
# Epoch 156/200
#  - 1s - loss: 0.0550 - val_loss: 0.0593
# Epoch 157/200
#  - 1s - loss: 0.0578 - val_loss: 0.0593
# Epoch 158/200
#  - 1s - loss: 0.0602 - val_loss: 0.0591
# Epoch 159/200
#  - 1s - loss: 0.0552 - val_loss: 0.0590
# Epoch 160/200
#  - 1s - loss: 0.0549 - val_loss: 0.0589
# Epoch 161/200
#  - 1s - loss: 0.0566 - val_loss: 0.0597
# Epoch 162/200
#  - 1s - loss: 0.0589 - val_loss: 0.0590
# Epoch 163/200
#  - 1s - loss: 0.0550 - val_loss: 0.0589
# Epoch 164/200
#  - 1s - loss: 0.0549 - val_loss: 0.0588
# Epoch 165/200
#  - 1s - loss: 0.0550 - val_loss: 0.0597
# Epoch 166/200
#  - 1s - loss: 0.0584 - val_loss: 0.0584
# Epoch 167/200
#  - 1s - loss: 0.0554 - val_loss: 0.0584
# Epoch 168/200
#  - 1s - loss: 0.0555 - val_loss: 0.0579
# Epoch 169/200
#  - 1s - loss: 0.0541 - val_loss: 0.0600
# Epoch 170/200
#  - 1s - loss: 0.0576 - val_loss: 0.0573
# Epoch 171/200
#  - 1s - loss: 0.0569 - val_loss: 0.0580
# Epoch 172/200
#  - 1s - loss: 0.0560 - val_loss: 0.0579
# Epoch 173/200
#  - 1s - loss: 0.0534 - val_loss: 0.0594
# Epoch 174/200
#  - 1s - loss: 0.0562 - val_loss: 0.0565
# Epoch 175/200
#  - 1s - loss: 0.0580 - val_loss: 0.0574
# Epoch 176/200
#  - 1s - loss: 0.0556 - val_loss: 0.0572
# Epoch 177/200
#  - 1s - loss: 0.0533 - val_loss: 0.0587
# Epoch 178/200
#  - 1s - loss: 0.0561 - val_loss: 0.0559
# Epoch 179/200
#  - 1s - loss: 0.0593 - val_loss: 0.0567
# Epoch 180/200
#  - 1s - loss: 0.0549 - val_loss: 0.0568
# Epoch 181/200
#  - 1s - loss: 0.0540 - val_loss: 0.0575
# Epoch 182/200
#  - 1s - loss: 0.0560 - val_loss: 0.0565
# Epoch 183/200
#  - 1s - loss: 0.0589 - val_loss: 0.0565
# Epoch 184/200
#  - 1s - loss: 0.0536 - val_loss: 0.0561
# Epoch 185/200
#  - 1s - loss: 0.0538 - val_loss: 0.0567
# Epoch 186/200
#  - 1s - loss: 0.0550 - val_loss: 0.0568
# Epoch 187/200
#  - 2s - loss: 0.0575 - val_loss: 0.0563
# Epoch 188/200
#  - 1s - loss: 0.0535 - val_loss: 0.0558
# Epoch 189/200
#  - 1s - loss: 0.0537 - val_loss: 0.0560
# Epoch 190/200
#  - 1s - loss: 0.0538 - val_loss: 0.0565
# Epoch 191/200
#  - 1s - loss: 0.0562 - val_loss: 0.0555
# Epoch 192/200
#  - 1s - loss: 0.0537 - val_loss: 0.0560
# Epoch 193/200
#  - 1s - loss: 0.0532 - val_loss: 0.0555
# Epoch 194/200
#  - 1s - loss: 0.0527 - val_loss: 0.0569
# Epoch 195/200
#  - 1s - loss: 0.0552 - val_loss: 0.0551
# Epoch 196/200
#  - 1s - loss: 0.0543 - val_loss: 0.0557
# Epoch 197/200
#  - 1s - loss: 0.0533 - val_loss: 0.0553
# Epoch 198/200
#  - 1s - loss: 0.0516 - val_loss: 0.0562
# Epoch 199/200
#  - 1s - loss: 0.0542 - val_loss: 0.0540
# Epoch 200/200
#  - 1s - loss: 0.0549 - val_loss: 0.0553

# %%
# plot history
fig=plt.figure(figsize=(12,6))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.text(100,0.014, "Fig. 4.4", size=12, ha="center",weight='bold')
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.legend()

# %%
test_y[-1:]
# Out:
# array([[0.57351963, 0.56819694, 0.45242848, 0.53892216, 0.53825682,
#         0.43978709, 0.84231537, 0.93878909, 0.86360612, 0.64471058,
#         0.53626081, 0.56220892, 0.50964737, 0.582169  , 0.37924152,
#         0.56886228, 0.52228876, 0.46906188, 0.81503659, 0.82834331,
#         0.82834331, 0.52894212, 0.43579508, 0.63539587]])

# %%
yhat=model.predict(test_X[-1:])
test_X_res = test_X.reshape((test_X.shape[0], n_days*n_features))

# invert scaling for forecast

yhat_last24=[]
ytrue_last24=[]

for i in np.arange(n_days):
    inv_yhat = concatenate((yhat[-1:,[i]], test_X_res[-1:, -5:]), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    inv_yhat = inv_yhat[:,0]
    yhat_last24.append(inv_yhat)

for i in np.arange(n_days):
    inv_y = concatenate((test_y[-1:,[i]], test_X_res[-1:, -5:]), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:,0]
    ytrue_last24.append(inv_y)

# %%
yhat=model.predict(np.reshape(test[-1,n_obs:],newshape=(1,n_days,n_features)))
test_X_res = test_X.reshape((test_X.shape[0], n_days*n_features))

# invert scaling for forecast

yhat_future=[]

for i in np.arange(n_days):
    inv_yhat = concatenate((yhat[-1:,[i]], test_X_res[-1:, -5:]), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    inv_yhat = inv_yhat[:,0]
    yhat_future.append(inv_yhat)

# %%
yhat_future
# Out:
# [array([153.17626657]),
#  array([147.75280609]),
#  array([139.05025966]),
#  array([144.73785934]),
#  array([153.00961014]),
#  array([160.74289665]),
#  array([171.59951974]),
#  array([194.07880499]),
#  array([194.21545018]),
#  array([161.36012476]),
#  array([153.74691008]),
#  array([166.93110614]),
#  array([148.62465491]),
#  array([148.46581932]),
#  array([135.17868919]),
#  array([144.65201824]),
#  array([148.88629915]),
#  array([153.30199125]),
#  array([172.02154044]),
#  array([192.2282763]),
#  array([191.393731]),
#  array([158.31795289]),
#  array([152.38526891]),
#  array([157.42630561])]

# %%
test_X.shape,yhat.shape,test_X_res.shape,test_y.shape
# Out:
# ((45, 24, 6), (1, 24), (45, 144), (45, 24))

# %%
#np.savetxt('../Result in CSV/Li_Scenario4.csv', yhat_future, delimiter=',')

# %% [markdown]
# ### Prediction Interval using simple univariate ARMA Model

# %%
import csv
import itertools
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm

# %%
Beer=pd.read_csv('../Scenario3/data_merged_final.csv',sep=',',index_col=0,usecols=[0,1])

# %%
mod = sm.tsa.statespace.SARIMAX(Beer,
                                order=(1, 0, 1),
                                enforce_stationarity=False,
                                enforce_invertibility=False,)

results = mod.fit()
print(results.summary())
# Out:
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   Beer   No. Observations:                  435
# Model:               SARIMAX(1, 0, 1)   Log Likelihood               -1872.418
# Date:                Tue, 23 Apr 2019   AIC                           3750.837
# Time:                        20:57:46   BIC                           3763.049
# Sample:                    01-01-1956   HQIC                          3755.658
#                          - 03-01-1992
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9968      0.004    237.065      0.000       0.989       1.005
# ma.L1         -0.3107      0.044     -7.066      0.000      -0.397      -0.225
# sigma2       335.4263     21.510     15.594      0.000     293.267     377.585
# ===================================================================================
# Ljung-Box (Q):                      824.88   Jarque-Bera (JB):                 3.08
# Prob(Q):                              0.00   Prob(JB):                         0.21
# Heteroskedasticity (H):               3.70   Skew:                             0.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
# Get forecast 24 steps ahead in future
pred_uc = results.get_forecast(steps=24)

# Get 95% confidence intervals of forecasts
pred_ci = pred_uc.conf_int(alpha=0.05)

# %%
s=pd.DataFrame(pred_uc.predicted_mean)
s.columns=['Beer']
s.set_index(s.columns[0])
s.index.name='Date'
s.index=s.index.to_period('D')

# %%
Beer.index = pd.to_datetime(Beer.index)
Beer.index=Beer.index.to_period('D')

# %%
fig, ax = plt.subplots(figsize=(12,6))
Beer.append(s)[300:].plot(ax=ax)
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.text(0.5,-0.15, "Fig. 4.5", size=12, ha="center", transform=ax.transAxes,weight='bold')
plt.legend(['Forcast','Prediction Interval'],loc=2)
plt.show()

# %% [markdown]
# ### Prediction Interval using simple vector AR model

# %%
dataset=pd.read_csv('dataset_stationary.csv',sep=',',index_col=0)

# %%
initial=dataset['Beer'][0]
end=dataset['Beer'][-1]

# %%
adf_test(dataset['Beer'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.973067
# p-value                          0.298506
# #Lags Used                      17.000000
# Number of Observations Used    404.000000
# Critical Value (1%)             -3.446640
# Critical Value (5%)             -2.868721
# Critical Value (10%)            -2.570595
# dtype: float64

# %%
model = VAR(dataset)
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
results = model.fit()
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 23, Apr, 2019
# Time:                     20:59:09
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                    44.7285
# Nobs:                     421.000    HQIC:                   44.4845
# Log likelihood:          -12872.7    FPE:                1.77902e+19
# AIC:                      44.3252    Det(Omega_mle):     1.61143e+19
# --------------------------------------------------------------------
# Results for equation Beer
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      24.919009         7.722018            3.227           0.001
# L1.Beer                     0.815589         0.031621           25.793           0.000
# L1.Car                      0.000500         0.000134            3.738           0.000
# L1.Temp                    -0.581454         0.317734           -1.830           0.067
# L1.Steel_log_diff         -41.452097         8.840429           -4.689           0.000
# L1.Gas_diff                -0.000760         0.000613           -1.240           0.215
# L1.Electricity_diff        -0.002055         0.004501           -0.456           0.648
# ======================================================================================
#
# Results for equation Car
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                   18900.952065      2838.684564            6.658           0.000
# L1.Beer                    -1.375852        11.624092           -0.118           0.906
# L1.Car                      0.534947         0.049164           10.881           0.000
# L1.Temp                  -277.825967       116.801791           -2.379           0.017
# L1.Steel_log_diff      -11720.620956      3249.822722           -3.607           0.000
# L1.Gas_diff                 0.148064         0.225420            0.657           0.511
# L1.Electricity_diff        -0.786027         1.654628           -0.475           0.635
# ======================================================================================
#
# Results for equation Temp
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       6.309131         0.857958            7.354           0.000
# L1.Beer                     0.023616         0.003513            6.722           0.000
# L1.Car                     -0.000068         0.000015           -4.593           0.000
# L1.Temp                     0.652618         0.035302           18.487           0.000
# L1.Steel_log_diff          -1.647115         0.982220           -1.677           0.094
# L1.Gas_diff                -0.000122         0.000068           -1.793           0.073
# L1.Electricity_diff         0.000270         0.000500            0.540           0.590
# ======================================================================================
#
# Results for equation Steel_log_diff
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.013669         0.039007           -0.350           0.726
# L1.Beer                    -0.000601         0.000160           -3.761           0.000
# L1.Car                      0.000003         0.000001            4.090           0.000
# L1.Temp                     0.001090         0.001605            0.679           0.497
# L1.Steel_log_diff          -0.371716         0.044656           -8.324           0.000
# L1.Gas_diff                 0.000006         0.000003            1.860           0.063
# L1.Electricity_diff        -0.000023         0.000023           -0.998           0.318
# ======================================================================================
#
# Results for equation Gas_diff
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                    -109.026632       651.204946           -0.167           0.867
# L1.Beer                    -2.334953         2.666610           -0.876           0.381
# L1.Car                     -0.003403         0.011278           -0.302           0.763
# L1.Temp                    23.606241        26.794771            0.881           0.378
# L1.Steel_log_diff        -420.152644       745.521591           -0.564           0.573
# L1.Gas_diff                -0.258889         0.051712           -5.006           0.000
# L1.Electricity_diff        -1.606077         0.379578           -4.231           0.000
# ======================================================================================
#
# Results for equation Electricity_diff
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                     -28.157938        86.436139           -0.326           0.745
# L1.Beer                    -0.541991         0.353946           -1.531           0.126
# L1.Car                     -0.000028         0.001497           -0.019           0.985
# L1.Temp                     4.668260         3.556540            1.313           0.189
# L1.Steel_log_diff         -44.351333        98.955035           -0.448           0.654
# L1.Gas_diff                 0.001369         0.006864            0.199           0.842
# L1.Electricity_diff        -0.459396         0.050382           -9.118           0.000
# ======================================================================================
#
# Correlation matrix of residuals
#                         Beer       Car      Temp  Steel_log_diff  Gas_diff  Electricity_diff
# Beer                1.000000  0.320034  0.283314        0.062173  0.065251          0.141373
# Car                 0.320034  1.000000 -0.205134       -0.093857  0.060066          0.074787
# Temp                0.283314 -0.205134  1.000000       -0.066707 -0.132304         -0.129305
# Steel_log_diff      0.062173 -0.093857 -0.066707        1.000000  0.037952          0.050563
# Gas_diff            0.065251  0.060066 -0.132304        0.037952  1.000000          0.421808
# Electricity_diff    0.141373  0.074787 -0.129305        0.050563  0.421808          1.000000

# %%
mid, lower, upper = results.forecast_interval(results.y[-results.k_ar:], steps=24,
                                           alpha=0.05)
fig = plotting.plot_var_forc(results.y, mid, lower, upper,
                             names=results.names, plot_stderr=True,fig=plt.figure(figsize=(12,30)))
